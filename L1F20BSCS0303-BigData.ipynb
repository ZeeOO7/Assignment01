# %% [markdown]
# # Assignment01 L1F20BSCS0303->Zeeshan.Ali

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from matplotlib import pyplot

# %%
aa = pd.read_csv("jsrt_metadata.csv")
aa.head(60)
# Out:
#         study_id  subtlety  size age  gender       x       y      state  \
# 0   JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0  malignant
# 1   JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0     benign
# 2   JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0  malignant
# 3   JPCLN004.png       5.0  14.0  68  Female   606.0   836.0     benign
# 4   JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0  malignant
# 5   JPCLN006.png       5.0  14.0  64  Female   660.0   524.0     benign
# 6   JPCLN007.png       5.0  18.0  69    Male   459.0   852.0  malignant
# 7   JPCLN008.png       5.0  10.0  44  Female   508.0   938.0     benign
# 8   JPCLN009.png       5.0  28.0  61  Female  1593.0   930.0  malignant
# 9   JPCLN010.png       5.0  25.0  60  Female   647.0   594.0  malignant
# 10  JPCLN011.png       5.0  20.0  68    Male   647.0   401.0     benign
# 11  JPCLN012.png       5.0  37.0  80    Male   268.0  1136.0  malignant
# ...

# %%
aa.head(10)
# Out:
#        study_id  subtlety  size age  gender       x       y      state  \
# 0  JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0  malignant
# 1  JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0     benign
# 2  JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0  malignant
# 3  JPCLN004.png       5.0  14.0  68  Female   606.0   836.0     benign
# 4  JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0  malignant
# 5  JPCLN006.png       5.0  14.0  64  Female   660.0   524.0     benign
# 6  JPCLN007.png       5.0  18.0  69    Male   459.0   852.0  malignant
# 7  JPCLN008.png       5.0  10.0  44  Female   508.0   938.0     benign
# 8  JPCLN009.png       5.0  28.0  61  Female  1593.0   930.0  malignant
# 9  JPCLN010.png       5.0  25.0  60  Female   647.0   594.0  malignant
#
#              position           diagnosis
# 0        l.upper lobe         lung cancer
# 1    l.upper lobe(S5)  pulmonary hematoma
# 2  l.upper lobe(S1+2)         lung cancer
# ...

# %% [markdown]
# # Data Filtering Process

# %%
c = aa['diagnosis'].value_counts().idxmax()

# %%
aa["diagnosis"].replace(np.nan,c,inplace=True)

# %%
aa['diagnosis'].isnull().sum()
# Out:
# 0

# %%
aa["diagnosis"].replace("unknown",np.nan,inplace=True)
aa["diagnosis"].isnull().sum()
# Out:
# 4

# %%
aa["diagnosis"].replace(np.nan,c,inplace=True)
aa["diagnosis"].isnull().sum()
# Out:
# 0

# %%
aa["position"].isnull().sum()
# Out:
# 93

# %%
v = aa["position"].value_counts().idxmax()
v
# Out:
# 'r.upper lobe(S2)'

# %%
aa["position"].replace(np.nan,v,inplace=True)

# %%
aa["position"].isnull().sum()
# Out:
# 0

# %%
aa["state"].replace("non-nodule",np.nan,inplace=True)

# %%
aa["state"].isnull().sum()
# Out:
# 93

# %%
q =aa["state"].value_counts().idxmax()

# %%
aa["state"].replace(np.nan,q,inplace=True)

# %%
aa["y"].isnull().sum()
# Out:
# 93

# %%
m1 = aa["y"].astype('float').mean()
m1
# Out:
# 868.6233766233767

# %%
aa["y"] = aa["y"].astype("float")
aa["y"]
# Out:
# 0       692.0
# 1      1090.0
# 2       447.0
# 3       836.0
# 4       692.0
#         ...
# 242       NaN
# 243       NaN
# 244       NaN
# 245       NaN
# 246       NaN
# Name: y, Length: 247, dtype: float64

# %%
aa["y"].replace(np.nan,m1,inplace=True)

# %%
aa["y"] = aa["y"].astype('int')
aa["y"]
# Out:
# 0       692
# 1      1090
# 2       447
# 3       836
# 4       692
#        ...
# 242     868
# 243     868
# 244     868
# 245     868
# 246     868
# Name: y, Length: 247, dtype: int32

# %%
d=aa["x"].astype('float').mean()

# %%
aa["x"].replace(np.nan,d,inplace=True)

# %%
aa["x"].isnull().sum()
# Out:
# 0

# %%
f = aa["size"].astype('float').mean()
aa["size"].replace(np.nan,f,inplace=True)

# %%
c = aa["subtlety"].astype('float').mean()
aa['subtlety'].replace(np.nan,c,inplace=True)

# %%
aa.tail(10)
# Out:
#          study_id  subtlety       size age  gender           x    y  \
# 237  JPCNN084.png   2.88961  17.246753  53  Female  937.324675  868
# 238  JPCNN085.png   2.88961  17.246753  68  Female  937.324675  868
# 239  JPCNN086.png   2.88961  17.246753  47    Male  937.324675  868
# 240  JPCNN087.png   2.88961  17.246753  77  Female  937.324675  868
# 241  JPCNN088.png   2.88961  17.246753  54    Male  937.324675  868
# 242  JPCNN089.png   2.88961  17.246753  50    Male  937.324675  868
# 243  JPCNN090.png   2.88961  17.246753  68  Female  937.324675  868
# 244  JPCNN091.png   2.88961  17.246753  81    Male  937.324675  868
# 245  JPCNN092.png   2.88961  17.246753  70  Female  937.324675  868
# 246  JPCNN093.png   2.88961  17.246753  41    Male  937.324675  868
#
#          state          position    diagnosis
# 237  malignant  r.upper lobe(S2)  lung cancer
# 238  malignant  r.upper lobe(S2)  lung cancer
# 239  malignant  r.upper lobe(S2)  lung cancer
# ...

# %%
aa.isnull().sum()
# Out:
# study_id     0
# subtlety     0
# size         0
# age          0
# gender       0
# x            0
# y            0
# state        0
# position     0
# diagnosis    0
# dtype: int64

# %%
aa
# Out:
#          study_id  subtlety       size age  gender            x     y  \
# 0    JPCLN001.png   5.00000  15.000000  53    Male  1634.000000   692
# 1    JPCLN002.png   5.00000  30.000000  78  Female  1614.000000  1090
# 2    JPCLN003.png   5.00000  30.000000  63  Female  1303.000000   447
# 3    JPCLN004.png   5.00000  14.000000  68  Female   606.000000   836
# 4    JPCLN005.png   5.00000  35.000000  73  Female  1438.000000   692
# ..            ...       ...        ...  ..     ...          ...   ...
# 242  JPCNN089.png   2.88961  17.246753  50    Male   937.324675   868
# 243  JPCNN090.png   2.88961  17.246753  68  Female   937.324675   868
# 244  JPCNN091.png   2.88961  17.246753  81    Male   937.324675   868
# 245  JPCNN092.png   2.88961  17.246753  70  Female   937.324675   868
# 246  JPCNN093.png   2.88961  17.246753  41    Male   937.324675   868
#
#          state            position           diagnosis
# 0    malignant        l.upper lobe         lung cancer
# ...

# %% [markdown]
# # Question01

# %%
aa['diagnosis'].value_counts() #Total number of patients of each disease
# Out:
# lung cancer                                       153
# lung cancer(adenocarcinoma)                        23
# tuberculoma                                        14
# granuloma                                           8
# lung cancer(bronchioloalveolar cell carcinoma)      7
# metastasis of colon cancer                          4
# inflammatory mass                                   4
# pulmonary tuberculosis                              3
# lung abscess                                        2
# Cryptococcosis                                      2
# lung cancer(squamous cell carcinoma)                2
# Inflammatory mass                                   2
# pulmonary hematoma                                  2
# susp. inflammatory mass                             2
# hamartoma                                           2
# sclerosing hemangioma                               2
# lung cancer(large cell carcinoma)                   1
# ...

# %%
plt.pyplot.hist(aa["diagnosis"],color='cyan',ec='black')
# Out:
# (array([157.,  45.,  11.,   5.,   8.,   7.,   3.,   3.,   4.,   4.]),
#  array([ 0.,  3.,  6.,  9., 12., 15., 18., 21., 24., 27., 30.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Question 02

# %%
aa[["diagnosis","state"]].value_counts() #Total number of patients of each disease with respect to the disease state
# Out:
# diagnosis                                       state
# lung cancer                                     malignant    149
# lung cancer(adenocarcinoma)                     malignant     23
# tuberculoma                                     benign        14
# granuloma                                       benign         8
# lung cancer(bronchioloalveolar cell carcinoma)  malignant      7
# lung cancer                                     benign         4
# metastasis of colon cancer                      malignant      4
# inflammatory mass                               benign         4
# pulmonary tuberculosis                          benign         3
# lung abscess                                    benign         2
# Inflammatory mass                               benign         2
# susp. inflammatory mass                         benign         2
# sclerosing hemangioma                           benign         2
# pulmonary hematoma                              benign         2
# ...

# %%
aa["state"].value_counts()
# Out:
# malignant    193
# benign        54
# Name: state, dtype: int64

# %%
#Percentage of Disease in state
plt.pyplot.pie(aa["state"].value_counts(),shadow=True,explode=[0,0.1],labels=['malignant','benign'],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1f875005f40>,
# ...
#  [Text(-0.850588847327074, 0.6974945252851811, 'malignant'),
#   Text(0.9279151774158769, -0.7609030316152393, 'benign')],
#  [Text(-0.4639575530874948, 0.38045155924646235, '78.1%'),
#   Text(0.5412838534925948, -0.44386010177555624, '21.9%')])

# %%
#Per% of each Disease with state
plt.pyplot.pie(aa[["diagnosis","state"]].value_counts(),shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f876885c40>,
# ...
#  [Text(-0.35054586834727886, 1.042649315054996, ''),
#   Text(-0.647695063423749, -0.8890956668528455, ''),
#   Text(-0.17415030162497125, -1.0861269135989273, ''),
#   Text(0.1325904426548767, -1.0919797500487745, ''),
#   Text(0.33725646230925976, -1.047023437479144, ''),
#   Text(0.4799715744094368, -0.9897612276498441, ''),
#   Text(0.5780255148670865, -0.9358880831395597, ''),
#   Text(0.670100048440955, -0.8723336088214358, ''),
#   Text(0.7450098066787193, -0.8092962300372698, ''),
#   Text(0.7949362888017328, -0.7603132885502714, ''),
#   Text(0.8325727279525352, -0.7189037854050249, ''),
#   Text(0.8680546281712871, -0.6756338968038895, ''),
#   Text(0.9012901690886234, -0.6306155969401652, ''),
#   Text(0.9321933434832768, -0.5839653845609942, ''),
#   Text(0.960684179852312, -0.5358039814908906, ''),
#   Text(0.9866889493620762, -0.486256020226755, ''),
#   Text(1.010140356644312, -0.43544972141282023, ''),
# ...

# %% [markdown]
# # Question 03

# %%
#The Number of male and female disease and its type: like which disease effect which number of male/female
aa[["diagnosis","gender"]].value_counts()
# Out:
# diagnosis                                       gender
# lung cancer                                     Female    78
#                                                 Male      75
# lung cancer(adenocarcinoma)                     Female    15
# tuberculoma                                     Male       9
# lung cancer(adenocarcinoma)                     Male       8
# granuloma                                       Male       6
# tuberculoma                                     Female     5
# lung cancer(bronchioloalveolar cell carcinoma)  Female     4
# pulmonary tuberculosis                          Male       3
# metastasis of colon cancer                      Female     3
# lung cancer(bronchioloalveolar cell carcinoma)  Male       3
# sclerosing hemangioma                           Female     2
# Inflammatory mass                               Female     2
# lung cancer(squamous cell carcinoma)            Male       2
# ...

# %%
aa["gender"].value_counts()
# Out:
# Female    128
# Male      119
# Name: gender, dtype: int64

# %%
#The per% of male and female effect with disease
plt.pyplot.pie(aa["gender"].value_counts(),labels=['Female','Male'],explode=[0,0],autopct='%1.1f%%',colors=['pink','cyan'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1f8766bb160>,
# ...
#  [Text(-0.06292471903937313, 1.098198743276378, 'Female'),
#   Text(0.06292471903937276, -1.098198743276378, 'Male')],
#  [Text(-0.03432257402147625, 0.5990174963325697, '51.8%'),
#   Text(0.034322574021476045, -0.5990174963325697, '48.2%')])

# %%
#Which disease effect which gender the Diagnosis with respect to gender
plt.pyplot.pie(aa[["diagnosis","gender"]].value_counts(),shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f8767415e0>,
# ...
#  [Text(0.6016430102375327, 0.9208831023709363, ''),
#   Text(-1.0773008612740451, 0.2223125149383201, ''),
#   Text(-0.6476951674776744, -0.889095591050854, ''),
#   Text(-0.35054585614479516, -1.042649319157555, ''),
#   Text(-0.11869114244678645, -1.0935778036814192, ''),
#   Text(0.07688716752992862, -1.0973096023772073, ''),
#   Text(0.2291589840822943, -1.0758653075614861, ''),
#   Text(0.35054579513237183, -1.0426493396703482, ''),
#   Text(0.4418649436946453, -1.0073506695951158, ''),
#   Text(0.517379252294703, -0.9707310179936429, ''),
#   Text(0.5898818964010903, -0.9284607413877302, ''),
#   Text(0.6476951258561053, -0.8890956213716521, ''),
#   Text(0.6920711842931162, -0.8550072957999387, ''),
#   Text(0.7346562949122993, -0.81870637492677, ''),
#   Text(0.7753402555947598, -0.7802867985902701, ''),
#   Text(0.8140177840339105, -0.7398479893035611, ''),
#   Text(0.8505887901859396, -0.6974945949683193, ''),
# ...
